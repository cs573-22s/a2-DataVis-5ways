# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cars-sample.csv")

# %%
df
# Out:
#     Unnamed: 0               Car Manufacturer   MPG  Cylinders  Displacement  \
# 0            5            torino         ford  17.0          8           302
# 1            6       galaxie 500         ford  15.0          8           429
# 2           13       torino (sw)         ford   NaN          8           351
# 3           18  mustang boss 302         ford   NaN          8           302
# 4           21    corona mark ii       toyota  24.0          4           113
# ..         ...               ...          ...   ...        ...           ...
# 92         393      civic (auto)        honda  32.0          4            91
# 93         398         granada l         ford  22.0          6           232
# 94         399         celica gt       toyota  32.0          4           144
# 95         402        mustang gl         ford  27.0          4           140
# 96         405            ranger         ford  28.0          4           120
#
# ...

# %%
plt.figure(figsize=(8, 6), dpi=80)
sns.set_style("darkgrid")
sns.scatterplot(x ='Weight', y= 'MPG',hue ='Manufacturer',size = 'Weight',
                palette = ['tab:olive','tab:pink','tab:red','tab:green','tab:cyan'],alpha = 0.4, data = df,
                size_norm =(1500,5000),sizes= (30,350),legend = 'brief')

plt.legend(bbox_to_anchor = (1.02,0.8),loc ='upper left',borderaxespad =0,fontsize = 'large',frameon = False,
           labelspacing = 0.55)
plt.xticks([2000,3000,4000,5000])
plt.yticks([10,20,30,40])


plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib.lines import Line2D
import pandas as pd
import numpy as np

# read in the data
car_data = pd.read_csv('cars-sample.csv')
#print(car_data)

# set figure size and legend handler
fig, holder = plt.subplots(figsize=(8, 6), dpi=100)

handles = [Line2D([0], [0], marker = 'o', color = 'w', markerfacecolor = v, label = k, markersize = 3) for k, v in colors.items()]
holder.legend(title="Manufacturer", handles=handles, bbox_to_anchor=(1.05, 1), loc="upper left")
# array of unique Manufacturers
# wtv = np.unique(car_data['Manufacturer'])
# print(wtv)

# map colors to Manufacturers
colors = {'bmw':'red', 'ford':'orange', 'honda':'green', 'mercedes':'blue', 'toyota':'purple'}

# make plot
plt.scatter(car_data['Weight'], car_data['MPG'], alpha=0.5, s=(car_data['Weight']**2*0.00003), c=car_data['Manufacturer'].map(colors))

plt.grid("True")
plt.xlabel("Weight")
plt.ylabel("MPG")
#plt.legend("")
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
import pandas as pd
cars = pd.read_csv("/Users/shanu/Documents/WPI/data_vis/project2/cars-sample.csv")

# %%
sns.relplot(x="Weight", y="MPG", hue="Manufacturer", size="Weight",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=cars)
plt.xticks(np.arange(2000, 6000,step=1000))
plt.yticks(np.arange(10,50,step=10))
plt.grid()
